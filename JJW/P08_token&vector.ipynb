# %% [markdown]
# ### 이제부터 할 일 (2시 55분)
# 1. 토큰화
#     - Okt
#     - 불용어 제거
# 2. 어휘사전 생성
#     - TfidfModel
#     -
# 3. 벡터화
#     - CountVectorizer
#     - TfidfVectorizer
#     - word2vec
#     - doc2vec
# 4. 모델링
#     - RNN
#     - LSTM
#     - GRU
#     - CNN

# %%
# 파일 불러오기
import pandas as pd
import numpy as np

file3 = pd.read_csv('../DATA/king_3.csv', encoding='utf-8', sep=';')
file3
# Out:
#        label year month  day  \
# 0          3  10년   10월  10일
# 1          3  10년   10월  10일
# 2          3  10년   10월  10일
# 3          3  10년   10월  11일
# 4          3  10년   10월  11일
# ...      ...  ...   ...  ...
# 30937      3  즉위년    9월   9일
# 30938      3  즉위년    9월   9일
# 30939      3  즉위년    9월   9일
# 30940      3  즉위년    9월   9일
# 30941      3   9년    7월   9일
#
#                                                     text
# 0       지신사(知申事) 정흠지(鄭欽之)가 포천(抱川)에 가서 그의 어머니를 뵙고 오기를 ...
# 1      병조에서 계하기를,  "강무(講武)는 군국(軍國)의 중대사(重大事)이온데, 공신(功...
# 2                                영평현(永平縣) 굴동(屈洞)에서 머물렀다.
# 3                              포천현(抱川縣) 매장원(每場院)에서 머물렀다.
# 4                       심한 안개가 끼어 몇 걸음 밖의 사람도 분별하지 못하였다.
# ...                                                  ...
# 30937  임금이 경복궁에 거둥하여 지신사(知申事) 하연·총제(摠制) 원민생을 보내어 사신을 ...
# 30938   함길도 함흥·화주(和州)·의천(宜川)에 우박이 와서 이를 맞은 기러기는 다 죽었다...
# 30939                          왜적이 제주의 미곡선[漕船]을 약탈하여 갔다.
# ...

# %%
# 결측치 제거
file3 = file3.dropna()
file3
# Out:
#        label year month  day  \
# 0          3  10년   10월  10일
# 1          3  10년   10월  10일
# 2          3  10년   10월  10일
# 3          3  10년   10월  11일
# 4          3  10년   10월  11일
# ...      ...  ...   ...  ...
# 30937      3  즉위년    9월   9일
# 30938      3  즉위년    9월   9일
# 30939      3  즉위년    9월   9일
# 30940      3  즉위년    9월   9일
# 30941      3   9년    7월   9일
#
#                                                     text
# 0       지신사(知申事) 정흠지(鄭欽之)가 포천(抱川)에 가서 그의 어머니를 뵙고 오기를 ...
# 1      병조에서 계하기를,  "강무(講武)는 군국(軍國)의 중대사(重大事)이온데, 공신(功...
# 2                                영평현(永平縣) 굴동(屈洞)에서 머물렀다.
# 3                              포천현(抱川縣) 매장원(每場院)에서 머물렀다.
# 4                       심한 안개가 끼어 몇 걸음 밖의 사람도 분별하지 못하였다.
# ...                                                  ...
# 30937  임금이 경복궁에 거둥하여 지신사(知申事) 하연·총제(摠制) 원민생을 보내어 사신을 ...
# 30938   함길도 함흥·화주(和州)·의천(宜川)에 우박이 와서 이를 맞은 기러기는 다 죽었다...
# 30939                          왜적이 제주의 미곡선[漕船]을 약탈하여 갔다.
# ...

# %%
# year, month, day에서 숫자만 남기고 int로 변환
# 1. 즉위년 = 0년
if file3['year'].str.contains('즉위년').any():
    file3['year'] = file3['year'].str.replace('즉위년', '0')

# 2. 숫자만 남기고 int로 변환
file3['year'] = file3['year'].str.extract('(\d+)').astype(int)
file3['month'] = file3['month'].str.extract('(\d+)').astype(int)
file3['day'] = file3['day'].str.extract('(\d+)').astype(int)
file3
# Out:
# C:\Users\wjs31\AppData\Local\Temp\ipykernel_10140\3621465360.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   file3['year'] = file3['year'].str.replace('즉위년', '0')
# C:\Users\wjs31\AppData\Local\Temp\ipykernel_10140\3621465360.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   file3['year'] = file3['year'].str.extract('(\d+)').astype(int)
# C:\Users\wjs31\AppData\Local\Temp\ipykernel_10140\3621465360.py:8: SettingWithCopyWarning:
# ...

# %%
# 3. year, month, day를 합쳐서 datetime으로 변환
file3['date'] = pd.to_datetime(file3[['year', 'month', 'day']])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\wjs31\anaconda3\envs\Torch_NLP\lib\site-packages\pandas\core\tools\datetimes.py:1197, in _assemble_from_unit_mappings(arg, errors, utc)
#    1196 try:
# -> 1197     values = to_datetime(values, format="%Y%m%d", errors=errors, utc=utc)
#    1198 except (TypeError, ValueError) as err:
#
# File c:\Users\wjs31\anaconda3\envs\Torch_NLP\lib\site-packages\pandas\core\tools\datetimes.py:1046, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1045 elif isinstance(arg, ABCSeries):
# -> 1046     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1047     if not cache_array.empty:
#
# File c:\Users\wjs31\anaconda3\envs\Torch_NLP\lib\site-packages\pandas\core\tools\datetimes.py:250, in _maybe_cache(arg, format, cache, convert_listlike)
# ...

# %% [markdown]
# ### 1. tokenize
#
# 1) Okt
# 2) soynlp

# %% [markdown]
# ### Okt : 토큰화하고 Vocab도 만들기

# %%
# Okt
from konlpy.tag import Okt
okt = Okt()

# %% [markdown]
# ### Soynlp : 파일을 불러와 학습시키고 토큰화
